# %%
import pandas as pd   
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns
from datetime import datetime

# %%
df_benefite = pd.read_csv('./data/Benefits_Cost_Sharing_PUF.csv')
# Out:
# C:\Users\aveen\AppData\Local\Temp\ipykernel_28180\2046971327.py:1: DtypeWarning: Columns (9,12,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_benefite = pd.read_csv('./data/Benefits_Cost_Sharing_PUF.csv')

# %%
df_benefite
# Out:
#          BusinessYear StateCode  IssuerId SourceName  ImportDate  \
# 0                2026        AK     21989       HIOS  2025-10-15
# 1                2026        AK     21989       HIOS  2025-10-15
# 2                2026        AK     21989       HIOS  2025-10-15
# 3                2026        AK     21989       HIOS  2025-10-15
# 4                2026        AK     21989       HIOS  2025-10-15
# ...               ...       ...       ...        ...         ...
# 1457947          2026        WY     83964       HIOS  2025-10-15
# 1457948          2026        WY     83964       HIOS  2025-10-15
# 1457949          2026        WY     83964       HIOS  2025-10-15
# 1457950          2026        WY     83964       HIOS  2025-10-15
# 1457951          2026        WY     83964       HIOS  2025-10-15
#
#         StandardComponentId             PlanId  \
# 0            21989AK0030001  21989AK0030001-00
# 1            21989AK0030001  21989AK0030001-00
# 2            21989AK0030001  21989AK0030001-00
# 3            21989AK0030001  21989AK0030001-00
# 4            21989AK0030001  21989AK0030001-00
# ...                     ...                ...
# 1457947      83964WY0040002  83964WY0040002-00
# 1457948      83964WY0040002  83964WY0040002-00
# 1457949      83964WY0040002  83964WY0040002-00
# 1457950      83964WY0040002  83964WY0040002-00
# 1457951      83964WY0040002  83964WY0040002-00
#
#                              BenefitName   CopayInnTier1 CopayInnTier2  ...  \
# 0                      Accidental Dental             NaN           NaN  ...
# 1              Basic Dental Care - Adult  Not Applicable           NaN  ...
# 2              Basic Dental Care - Child  Not Applicable           NaN  ...
# 3           Dental Check-Up for Children  Not Applicable           NaN  ...
# 4              Major Dental Care - Adult  Not Applicable           NaN  ...
# ...                                  ...             ...           ...  ...
# 1457947        Major Dental Care - Adult           $0.00           NaN  ...
# 1457948        Major Dental Care - Child           $0.00           NaN  ...
# 1457949              Orthodontia - Adult             NaN           NaN  ...
# 1457950              Orthodontia - Child           $0.00           NaN  ...
# 1457951  Routine Dental Services (Adult)           $0.00           NaN  ...
#
#         IsEHB    IsCovered QuantLimitOnSvc LimitQty              LimitUnit  \
# 0         NaN  Not Covered             NaN      NaN                    NaN
# 1         NaN      Covered             NaN      NaN                    NaN
# 2         Yes      Covered             NaN      NaN                    NaN
# 3         Yes      Covered             Yes      2.0       Exam(s) per Year
# 4         NaN      Covered             NaN      NaN                    NaN
# ...       ...          ...             ...      ...                    ...
# 1457947   NaN      Covered             NaN      NaN                    NaN
# 1457948   Yes      Covered             NaN      NaN                    NaN
# 1457949   NaN  Not Covered             NaN      NaN                    NaN
# 1457950   Yes      Covered             NaN      NaN                    NaN
# 1457951   NaN      Covered             Yes      1.0  Visit(s) per 6 Months
#
#                          Exclusions  \
# 0                               NaN
# 1        See policy for exclusions.
# 2        See policy for exclusions.
# 3        See policy for exclusions.
# 4        See policy for exclusions.
# ...                             ...
# 1457947                         NaN
# 1457948                         NaN
# 1457949                         NaN
# 1457950                         NaN
# 1457951                         NaN
#
#                                                Explanation  \
# 0                                                      NaN
# 1        All dental services are subject to an annual m...
# 2                                   See policy for limits.
# 3                             See policy for other limits.
# 4        All dental services are subject to an annual m...
# ...                                                    ...
# 1457947                                                NaN
# 1457948                                                NaN
# 1457949                                                NaN
# 1457950                                                NaN
# 1457951                   Limited to one every six months.
#
#                 EHBVarReason IsExclFromInnMOOP IsExclFromOonMOOP
# 0                        NaN               NaN               NaN
# 1                    Not EHB               Yes               Yes
# 2        Substantially Equal                No                No
# 3        Substantially Equal                No                No
# 4                    Not EHB               Yes               Yes
# ...                      ...               ...               ...
# 1457947              Not EHB               Yes               Yes
# 1457948                  NaN                No               Yes
# 1457949                  NaN               NaN               NaN
# 1457950                  NaN                No               Yes
# 1457951              Not EHB               Yes               Yes
#
# [1457952 rows x 24 columns]

# %%
df_benefite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1457952 entries, 0 to 1457951
# Data columns (total 24 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   BusinessYear         1457952 non-null  int64
#  1   StateCode            1457952 non-null  object
#  2   IssuerId             1457952 non-null  int64
#  3   SourceName           1457952 non-null  object
#  4   ImportDate           1457952 non-null  object
#  5   StandardComponentId  1457952 non-null  object
#  6   PlanId               1457952 non-null  object
#  7   BenefitName          1457952 non-null  object
#  8   CopayInnTier1        1122132 non-null  object
#  9   CopayInnTier2        278936 non-null   object
#  10  CopayOutofNet        1122132 non-null  object
#  11  CoinsInnTier1        1122132 non-null  object
#  12  CoinsInnTier2        278936 non-null   object
#  13  CoinsOutofNet        1122132 non-null  object
#  14  IsEHB                1091796 non-null  object
#  15  IsCovered            1457952 non-null  object
#  16  QuantLimitOnSvc      582745 non-null   object
#  17  LimitQty             200646 non-null   float64
#  18  LimitUnit            200646 non-null   object
#  19  Exclusions           87380 non-null    object
#  20  Explanation          493199 non-null   object
#  21  EHBVarReason         307232 non-null   object
#  22  IsExclFromInnMOOP    1122132 non-null  object
#  23  IsExclFromOonMOOP    1122132 non-null  object
# dtypes: float64(1), int64(2), object(21)
# memory usage: 267.0+ MB

# %%
# 1.	What health insurance plans are most offered in the United States through the federal marketplace?
# 2.	What health insurance plans are most offered in Tennessee?
# 3.	What is the average price difference between plans that include dental coverage and plans that do not?
# 4.	What is the average price difference between plans that include vision coverage and plans that do not?
# 5.	How does the uninsured rate in the United States change across different income levels?
# 6.	What is the gender breakdown of people who do not have health insurance?
# 7.	What additional insights can be found by combining health insurance plan data with demographic insurance data?
